# %%
age = "34"

# %%
print(age)

# %%
type(age)

# %%
print(int(age)+1)

# %%
age = input("Enter your age")
# Out:
# Enter your age 50

# %%
type(age)
# Out:
# str

# %%
myage = int(age)

# %%
print(myage)
# Out:
# 50

# %%
type(myage)
# Out:
# int
