# %%
print(5 + 3)
print(10 - 5)
# Out:
# 8
# 5

# %%
print(5 * 3)
print(15 / 5)
print(17 // 3) #retursn int value
# Out:
# 15
# 3.0
# 5

# %%
print(2 ** 3) # exponent
print(10 % 3)
# Out:
# 8
# 1

# %%
print( 5 == 5)  
print(7 != 3)   
print(10 > 2)   
print(4 < 1)
# Out:
# True
# True
# True
# False

# %%
#Logical Operators
print(True and False)
print(True or False)
print(not True)
# Out:
# False
# True
# False
