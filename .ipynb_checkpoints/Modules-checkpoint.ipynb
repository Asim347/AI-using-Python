# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt
print(sqrt(16))
# Out:
# 4.0

# %%
import my_module
my_module.greet()
# Out:
# Hello this is Asim Ali!

# %%
import random

print(random.randint(1, 10))   # random number between 1-10
print(random.random())         # float between 0 and 1

names = ["Ali", "Ahmed", "Sara"]
print(random.choice(names))    # random item
# Out:
# 3
# 0.7377392132661338
# Ali

# %%
import datetime

now = datetime.datetime.now()
print(now)

print(now.date())
print(now.year)
# Out:
# 2026-04-13 10:11:30.201755
# 2026-04-13
# 2026

# %%
import os

print(os.getcwd())      # current directory
os.mkdir("test_folder") # create folder
print(os.listdir())     # list files/folders
# Out:
# E:\Asim\Python
# ['.ipynb_checkpoints', 'Conditional.ipynb', 'Functions.ipynb', 'intro.ipynb', 'Loops.ipynb', 'Modules.ipynb', 'my_module.py', 'Operators.ipynb', 'test_folder', 'Type_Casting.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb', '__pycache__']

# %%
import json

data = '{"name": "Ali", "age": 20}'
parsed = json.loads(data)

print(parsed["name"])   # Ali

new_json = json.dumps(parsed)
print(new_json)
# Out:
# Ali
# {"name": "Ali", "age": 20}
